# %% [markdown]
# In this notebook, we compute LTE intensities (and save them in .npy files). Then another notebook may postprocess them in order to create plots.

# %%
import magritte.core     as magritte   # Core functionality
import magritte.plot     as plot       # Plotting
import magritte.tools    as tools      # Save fits
import numpy as np
import os
import time                            # For timing

from astropy import units              # Unit conversions

# %% [markdown]
# Define a working directory (you will have to change this). We assume here that the scripts of the this example have already been executed and go back to that working directory.

# %%
wdir = "/STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/"

# %% [markdown]
# Define file names.

# %%
model_file_haar = os.path.join(wdir, 'wind_red_haar.hdf5')   # reduced 3D Phantom Magritte model
model_file_gmsh = os.path.join(wdir, 'wind_red_gmsh.hdf5')   # reduced 3D Phantom Magritte model
model_file_rec = os.path.join(wdir, 'wind_red_rec.hdf5')   # reduced 3D Phantom Magritte model
model_file_original = os.path.join(wdir, 'model_Phantom_3D.hdf5')   # original 3D Phantom Magritte model

model_file_gmsh_save = os.path.join(wdir, 'wind_red_gmsh_save.hdf5')   # reduced 3D Phantom Magritte model
model_file_rec_save = os.path.join(wdir, 'wind_red_rec_save.hdf5')   # reduced 3D Phantom Magritte model
model_file_original_save = os.path.join(wdir, 'model_Phantom_3D_save.hdf5')   # original 3D Phantom Magritte model


J_file_original = os.path.join(wdir, 'J_original_full_NLTE.npy')
J_file_haar = os.path.join(wdir, 'J_haar_full_NLTE.npy')
J_file_gmsh = os.path.join(wdir, 'J_gmsh_full_NLTE.npy')
J_file_rec = os.path.join(wdir, 'J_rec_full_NLTE.npy')

# %% [markdown]
# Load all models

# %%
model_haar = magritte.Model(model_file_haar)
model_gmsh = magritte.Model(model_file_gmsh)
model_original = magritte.Model(model_file_original)
model_rec = magritte.Model(model_file_rec)
# Out:
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/wind_red_haar.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 88615
#   nrays      = 48
#   nboundary  = 985
#   nfreqs     = 280
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 7
# -------------------------------------------
#
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/wind_red_gmsh.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 91960
#   nrays      = 48
#   nboundary  = 4792
#   nfreqs     = 280
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 7
# -------------------------------------------
#
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/model_Phantom_3D.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 1096863
#   nrays      = 48
#   nboundary  = 1200
#   nfreqs     = 280
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 7
# -------------------------------------------
#
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/wind_red_rec.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 84525
#   nrays      = 48
#   nboundary  = 1200
#   nfreqs     = 280
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 7
# -------------------------------------------

# %% [markdown]
# Initialize all models.

# %%
model_haar.compute_spectral_discretisation ()
model_haar.compute_inverse_line_widths     ()
model_haar.compute_LTE_level_populations   ()

model_gmsh.compute_spectral_discretisation ()
model_gmsh.compute_inverse_line_widths     ()
model_gmsh.compute_LTE_level_populations   ()

model_rec.compute_spectral_discretisation ()
model_rec.compute_inverse_line_widths     ()
model_rec.compute_LTE_level_populations   ()

model_original.compute_spectral_discretisation ()
model_original.compute_inverse_line_widths     ()
model_original.compute_LTE_level_populations   ()
# Out:
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# 0

# %% [markdown]
# Use sparse feautrier solver to compute the radiation field (using all CO lines) for all solvers.

# %%
start = time.time()
model_haar.compute_level_populations_sparse(True, 10)
end = time.time()
print("Haar remesh computation time: ", end - start)
# Out:
# Haar remesh computation time:  375.14605474472046
# using ng acceleration?

# %% [markdown]
# Save in .npy file.

# %%
np.save(J_file_haar, np.array(model_haar.lines.lineProducingSpecies[0].J))
# Out:
# 0
# Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 36.144334 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 0.707880 seconds
# Already 0.36037 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 72.638370 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 1.305785 seconds
# Already 0.371434 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 109.206724 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 3.652970 seconds
# Already 22.0347 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 3 used order: 3
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 145.490577 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 4.161108 seconds
# Already 89.7994 % converged!
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 181.603985 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 4.684519 seconds
# Already 95.3365 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 2 used order: 2
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 6
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 218.328316 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 5.368745 seconds
# Already 96.6988 % converged!
# using ng acceleration? 0
# Starting iteration 7
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 254.879012 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 6.040812 seconds
# Already 96.0104 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 2 used order: 2
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 8
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 291.495548 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 6.516918 seconds
# Already 97.9301 % converged!
# using ng acceleration? 0
# Starting iteration 9
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 328.465421 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 7.082687 seconds
# Already 96.7916 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 2 used order: 2
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 10
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 365.240080 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 7.608622 seconds
# Already 98.4992 % converged!
# Converged after 10 iterations

# %%
start = time.time()
model_gmsh.compute_level_populations_sparse(True, 10)
end = time.time()
print("GMSH remesh computation time: ", end - start)
np.save(J_file_gmsh, np.array(model_gmsh.lines.lineProducingSpecies[0].J))
# Out:
# using ng acceleration? 0
# Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# GMSH remesh computation time:  344.9690089225769
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 33.087798 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 1.301923 seconds
# Already 2.40454 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 68.861010 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 1.840838 seconds
# Already 2.54856 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 101.646118 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 2.335714 seconds
# Already 41.5816 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 135.160905 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 3.189368 seconds
# Already 91.7181 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 4 used order: 4
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 168.226345 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 3.906095 seconds
# Already 94.2539 % converged!
# using ng acceleration? 0
# Starting iteration 6
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 201.154136 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 4.762796 seconds
# Already 95.5999 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 2 used order: 2
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 7
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 234.162644 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 5.323619 seconds
# Already 97.8174 % converged!
# using ng acceleration? 0
# Starting iteration 8
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 267.159851 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 5.951505 seconds
# Already 96.2686 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 2 used order: 2
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 9
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 300.449495 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 7.626535 seconds
# Already 97.7867 % converged!
# using ng acceleration? 0
# Starting iteration 10
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 333.729055 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 8.944838 seconds
# Already 96.2984 % converged!
# Converged after 10 iterations

# %%
model_gmsh.write(model_file_gmsh_save)
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 2
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# --- colpoar = 1
# Writing collisionPartner...
# (l, c) = 0, 1
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...

# %%
start = time.time()
model_rec.compute_level_populations_sparse(True, 10)
end = time.time()
print("Recusive remesh computation time: ", end - start)
np.save(J_file_rec, np.array(model_rec.lines.lineProducingSpecies[0].J))
# Out:
# using ng acceleration? 0
# Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# Recusive remesh computation time:  394.63408756256104
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 38.250529 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 0.622936 seconds
# Already 2.80087 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 76.715715 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 3.581583 seconds
# Already 2.97597 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 115.350745 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 4.065816 seconds
# Already 44.6703 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 154.262111 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 4.635830 seconds
# Already 91.2858 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 4 used order: 4
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 192.030637 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 5.535030 seconds
# Already 93.986 % converged!
# using ng acceleration? 0
# Starting iteration 6
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 229.848774 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 6.030912 seconds
# Already 95.8836 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 2 used order: 2
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 7
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 268.074623 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 6.615203 seconds
# Already 97.536 % converged!
# using ng acceleration? 0
# Starting iteration 8
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 305.838697 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 9.527041 seconds
# Already 96.7423 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 2 used order: 2
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 9
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 343.859015 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 10.126246 seconds
# Already 98.6547 % converged!
# using ng acceleration? 0
# Starting iteration 10
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 381.818598 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 10.567075 seconds
# Already 96.796 % converged!
# Converged after 10 iterations

# %%
model_rec.write(model_file_rec_save)
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 2
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# --- colpoar = 1
# Writing collisionPartner...
# (l, c) = 0, 1
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...

# %% [markdown]
# Use sparse solver for large model (as it is quite a bit more memory-intensive and will probably crash this script); Takes quite some time to run

# %%
start = time.time()
model_original.compute_level_populations_sparse(True, 10)
np.save(J_file_original, np.array(model_original.lines.lineProducingSpecies[0].J))
end = time.time()
print("Original mesh computation time: ", end - start)
model_original.write(model_file_original_save)
# Out:
# using ng acceleration? 0
# Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 1050.208168 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 8.260487 seconds
# Already 0.917221 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 2085.923556 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 14.521313 seconds
# Already 1.23758 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 3123.544893 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 20.961560 seconds
# Already 28.8162 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 4157.912745 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 27.128659 seconds
# Already 93.5693 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 4 used order: 4
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 5194.274962 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 33.358126 seconds
# Already 96.3427 % converged!
# using ng acceleration? 0
# Starting iteration 6
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 6234.668806 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 39.526007 seconds
# Already 98.7016 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 2 used order: 2
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 7
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 7269.256724 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 48.079014 seconds
# Already 99.3893 % converged!
# using ng acceleration? 0
# Starting iteration 8
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 8304.529810 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 54.266906 seconds
# Already 99.0906 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 2 used order: 2
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# using ng acceleration? 0
# Starting iteration 9
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 9340.005990 seconds
# Minor warning: population inversions detected; Magritte does not handle masers, so setting affected populations to LTE.
# Tot | Compute Statistical Equilibrium : 60.435040 seconds
# Already 99.6461 % converged!
# Converged after 9 iterations
# Original mesh computation time:  9429.160588264465
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 2
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# --- colpoar = 1
# Writing collisionPartner...
# (l, c) = 0, 1
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
