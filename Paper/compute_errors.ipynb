# %% [markdown]
# In this notebook, we compute LTE intensities (and save them in .npy files). Then another notebook may postprocess them in order to create plots.

# %%
import magritte.core     as magritte   # Core functionality
import magritte.plot     as plot       # Plotting
import magritte.tools    as tools      # Save fits
import numpy as np
import os
import time                            # For timing

from astropy import units              # Unit conversions

# %% [markdown]
# Define a working directory (you will have to change this). We assume here that the scripts of the this example have already been executed and go back to that working directory.

# %%
wdir = "/STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/"

# %% [markdown]
# Define file names.

# %%
model_file_haar = os.path.join(wdir, 'wind_red_haar.hdf5')   # reduced 3D Phantom Magritte model
model_file_gmsh = os.path.join(wdir, 'wind_red_gmsh.hdf5')   # reduced 3D Phantom Magritte model
model_file_rec = os.path.join(wdir, 'wind_red_rec.hdf5')   # reduced 3D Phantom Magritte model
model_file_original = os.path.join(wdir, 'model_Phantom_3D.hdf5')   # original 3D Phantom Magritte model

model_file_gmsh_save = os.path.join(wdir, 'wind_red_gmsh_save.hdf5')   # reduced 3D Phantom Magritte model
model_file_rec_save = os.path.join(wdir, 'wind_red_rec_save.hdf5')   # reduced 3D Phantom Magritte model
model_file_original_save = os.path.join(wdir, 'model_Phantom_3D_save.hdf5')   # original 3D Phantom Magritte model


J_file_original = os.path.join(wdir, 'J_original_full_NLTE.npy')
J_file_haar = os.path.join(wdir, 'J_haar_full_NLTE.npy')
J_file_gmsh = os.path.join(wdir, 'J_gmsh_full_NLTE.npy')
J_file_rec = os.path.join(wdir, 'J_rec_full_NLTE.npy')

# %% [markdown]
# Load all models

# %%
model_haar = magritte.Model(model_file_haar)
model_gmsh = magritte.Model(model_file_gmsh)
model_original = magritte.Model(model_file_original)
model_rec = magritte.Model(model_file_rec)
# Out:
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/wind_red_haar.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 88615
#   nrays      = 48
#   nboundary  = 985
#   nfreqs     = 280
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 7
# -------------------------------------------
#
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/wind_red_gmsh.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 91960
#   nrays      = 48
#   nboundary  = 4792
#   nfreqs     = 280
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 7
# -------------------------------------------
#
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/model_Phantom_3D.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 1096863
#   nrays      = 48
#   nboundary  = 1200
#   nfreqs     = 280
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 7
# -------------------------------------------
#
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /STER/thomasc/Magritte_Paper_Astronomy_Computing/models/Phantom_3D/wind_red_rec.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym CO
# nlev = 41
# nrad = 40
# Reading collisionPartner...
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 84525
#   nrays      = 48
#   nboundary  = 1200
#   nfreqs     = 280
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 40
#   nquads     = 7
# -------------------------------------------

# %% [markdown]
# Initialize all models.

# %%
model_haar.compute_spectral_discretisation ()
model_haar.compute_inverse_line_widths     ()
model_haar.compute_LTE_level_populations   ()

model_gmsh.compute_spectral_discretisation ()
model_gmsh.compute_inverse_line_widths     ()
model_gmsh.compute_LTE_level_populations   ()

model_rec.compute_spectral_discretisation ()
model_rec.compute_inverse_line_widths     ()
model_rec.compute_LTE_level_populations   ()

model_original.compute_spectral_discretisation ()
model_original.compute_inverse_line_widths     ()
model_original.compute_LTE_level_populations   ()
# Out:
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# 0

# %% [markdown]
# Use sparse feautrier solver to compute the radiation field (using all CO lines) for all solvers.

# %%
start = time.time()
model_haar.compute_level_populations_sparse(True, 10)
end = time.time()
print("Haar remesh computation time: ", end - start)
# Out:
# using ng acceleration? 0
# Haar remesh computation time: Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 34.021783 seconds
# Tot | Compute Statistical Equilibrium : 1.671275 seconds
# Already 0.000385334 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 68.787628 seconds
# Tot | Compute Statistical Equilibrium : 2.061866 seconds
# Already 0.042139 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 103.332552 seconds
# Tot | Compute Statistical Equilibrium : 2.449173 seconds
# Already 22.4071 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 138.094367 seconds
# Tot | Compute Statistical Equilibrium : 2.840725 seconds
# Already 91.5676 % converged!
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 172.733495 seconds
# Tot | Compute Statistical Equilibrium : 4.653835 seconds
# Already 98.5287 % converged!
# using ng acceleration? 0
# Starting iteration 6
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 207.314542 seconds
# Tot | Compute Statistical Equilibrium : 5.123710 seconds
# Already 99.7576 % converged!
# Converged after 6 iterations
#  213.78208303451538

# %% [markdown]
# Save in .npy file.

# %%
np.save(J_file_haar, np.array(model_haar.lines.lineProducingSpecies[0].J))

# %%
start = time.time()
model_gmsh.compute_level_populations_sparse(True, 10)
end = time.time()
print("GMSH remesh computation time: ", end - start)
np.save(J_file_gmsh, np.array(model_gmsh.lines.lineProducingSpecies[0].J))
# Out:
# using ng acceleration? GMSH remesh computation time:  197.8548104763031
# 0
# Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 31.930533 seconds
# Tot | Compute Statistical Equilibrium : 0.576624 seconds
# Already 0.00265227 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 63.838009 seconds
# Tot | Compute Statistical Equilibrium : 1.023542 seconds
# Already 0.197329 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 96.436526 seconds
# Tot | Compute Statistical Equilibrium : 1.381516 seconds
# Already 43.4506 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 128.966482 seconds
# Tot | Compute Statistical Equilibrium : 1.814944 seconds
# Already 94.0691 % converged!
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 161.121888 seconds
# Tot | Compute Statistical Equilibrium : 2.470017 seconds
# Already 99.1425 % converged!
# using ng acceleration? 0
# Starting iteration 6
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 193.396600 seconds
# Tot | Compute Statistical Equilibrium : 2.944715 seconds
# Already 99.8318 % converged!
# Converged after 6 iterations

# %%
model_gmsh.write(model_file_gmsh_save)
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 2
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# --- colpoar = 1
# Writing collisionPartner...
# (l, c) = 0, 1
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...

# %%
start = time.time()
model_rec.compute_level_populations_sparse(True, 10)
end = time.time()
print("Recusive remesh computation time: ", end - start)
np.save(J_file_rec, np.array(model_rec.lines.lineProducingSpecies[0].J))
# Out:
# using ng acceleration? 0
# Starting iteration 1
# Computing the radiation field...
# Recusive remesh computation time:  229.16991519927979
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 37.469422 seconds
# Tot | Compute Statistical Equilibrium : 0.611783 seconds
# Already 0.00259701 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 74.668600 seconds
# Tot | Compute Statistical Equilibrium : 1.069102 seconds
# Already 0.255257 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 111.987938 seconds
# Tot | Compute Statistical Equilibrium : 1.706181 seconds
# Already 46.2302 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 149.528884 seconds
# Tot | Compute Statistical Equilibrium : 2.132291 seconds
# Already 94.2686 % converged!
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 187.083824 seconds
# Tot | Compute Statistical Equilibrium : 3.273659 seconds
# Already 99.2116 % converged!
# using ng acceleration? 0
# Starting iteration 6
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 224.358928 seconds
# Tot | Compute Statistical Equilibrium : 3.600985 seconds
# Already 99.8459 % converged!
# Converged after 6 iterations

# %%
model_rec.write(model_file_rec_save)
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 2
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# --- colpoar = 1
# Writing collisionPartner...
# (l, c) = 0, 1
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...

# %% [markdown]
# Use sparse solver for large model (as it is quite a bit more memory-intensive and will probably crash this script); Takes quite some time to run

# %%
start = time.time()
model_original.compute_level_populations_sparse(True, 10)
np.save(J_file_original, np.array(model_original.lines.lineProducingSpecies[0].J))
end = time.time()
print("Original mesh computation time: ", end - start)
model_original.write(model_file_original_save)
# Out:
# using ng acceleration? 0
# Starting iteration 1
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 1027.005286 seconds
# Tot | Compute Statistical Equilibrium : 6.263471 seconds
# Already 0.00233037 % converged!
# using ng acceleration? 0
# Starting iteration 2
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 2056.794655 seconds
# Tot | Compute Statistical Equilibrium : 11.055685 seconds
# Already 0.380555 % converged!
# using ng acceleration? 0
# Starting iteration 3
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 3085.792870 seconds
# Tot | Compute Statistical Equilibrium : 16.450211 seconds
# Already 29.8978 % converged!
# using ng acceleration? 0
# Starting iteration 4
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 4114.216197 seconds
# Tot | Compute Statistical Equilibrium : 23.156813 seconds
# Already 96.6139 % converged!
# using ng acceleration? 1
# Ng acceleration max order: 4 used order: 4
# using ng acceleration? 0
# Starting iteration 5
# Computing the radiation field...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# Tot | Compute Radiation Field : 5145.603473 seconds
# Tot | Compute Statistical Equilibrium : 27.808522 seconds
# Already 99.9452 % converged!
# Converged after 5 iterations
# Original mesh computation time:  5191.497071266174
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 2
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# --- colpoar = 1
# Writing collisionPartner...
# (l, c) = 0, 1
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
